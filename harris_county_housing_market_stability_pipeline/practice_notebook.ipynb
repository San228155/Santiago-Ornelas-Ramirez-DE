# %%
df = spark.read.table('harris_county_catalog.etl.bronze_to_silver_zip')

# %%
display(df)

# %%
display(spark.read.table('harris_county_catalog.config.pipeline_config'))

# %%
for file in ['zip']:
    for quality in ['bronze', 'silver']:
        path = f'/Volumes/harris_county_catalog/etl/landing/checkpoint/{quality}/{file}/'
        dbutils.fs.mkdirs(path)

# %%
# %sql
TABLE harris_county_catalog.config.pipeline_config

# %% [markdown]
# TODO:
# - make the aggregations into customer, product and sales tables
# -

# %%
import sys
from typing import Any
from pyspark.sql import DataFrame
from pyspark.sql import functions as F, coalesce 

sys.path.append('/Workspace/Santiago-Ornelas-Ramirez/bike_data_set/bike_data_project/')

from config.customer_gold_metadata import (
    customer_gold_metadata,
    product_gold_metadata,
    sales_gold_meta_data
)

# %% [markdown]
# read the table
# for the variables imported from customer gold metadata
# we check the name
# we gather the join and join type
# and we gatehr tables
# first table must be set to the base (if it is unique we go to the select)
# just make a for loop joining on the base

# %%
gold_tables = [
  customer_gold_metadata,
  product_gold_metadata,
  sales_gold_meta_data
]


input_path = "bike_data_lakehouse.silver."


# for table_metadata in gold_tables:
